# %% [markdown]
# ## Imports
# - Place %%pycodestyle at the top of any cell to check python syntax

# %%
# %load_ext pycodestyle_magic

# Common imports
import pandas as pd
import numpy as np
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
import shap

# Import from my GitHub
from getxgboostmodel.getxgboostmodel import get_xgboost_model
from randomizedgridsearch.randomizedgridsearch import RandomizedGridSearch
from transformers.transformers import *
# Out:
# lightgbm is installed...but failed to load!

# %% [markdown]
# ## Initialize

# %%
# Example dataset
boston_data = load_boston()

# Extract pandas dataframe and target
X = pd.DataFrame(boston_data['data']).copy().values
y = pd.DataFrame(boston_data['target']).copy().values

# Train/test split
train_X, test_X, train_y, test_y = train_test_split(
    X, y, test_size=0.20, random_state=42)
train_X, test_X = train_X, test_X
train_y, test_y = train_y.reshape(-1, 1), test_y.reshape(-1, 1)

# An okay model fit to the data
try:
    xgb_model
except:
    xgb_model = get_xgboost_model(train_X, train_y)

# Pipeline
pipe = Pipeline([('standard_scaler', StandardScalerTransform()),
                 ('min_max_scaler', MinMaxScalerTransform()),
                 ('binarizer', BinarizerTransform()), 
                 ('k_bins_discretizer', KBinsDiscretizerTransform()),
                 ('k_bins_discretizer2', KBinsDiscretizerTransform2()),
                 ('k_bins_discretizer3', KBinsDiscretizerTransform3()),                 
                 ('model', xgb_model)])

# Find the number of features
num_features = train_X.shape[1]

# Testing with these indices
indices = list(range(num_features))

# Default 
default_values = [None]*num_features

# True values
true_values = [True]*num_features

# Scalers
scaler_values = [None]*num_features

# Possible configurations [None, True, or False] - None means not decided yet
param_distributions = {
    'standard_scaler': default_values,
    'min_max_scaler': default_values,
    'k_bins_discretizer': default_values,
    'k_bins_discretizer2': default_values,
    'k_bins_discretizer3': default_values,    
    'binarizer': default_values,    
}

experiments_results = pd.DataFrame()

# %% [markdown]
# ## Run the Experiments

# %%
for iteration in range(20):
    # Randomly search the space n_iter times
    experiments_results_temp = RandomizedGridSearch(
        n_experiments=100,
        pipe=pipe,
        param_distributions=param_distributions,
        train_X=train_X,
        train_y=train_y,
        test_X=test_X,
        test_y=test_y,
        scoring='neg_mean_squared_error')
    
    # Append to experiment results
    experiments_results = experiments_results.append(experiments_results_temp, ignore_index=True)
    
    # Ignore past data
    # experiments_results = experiments_results_temp

    # Drop score
    experiments_X_df = experiments_results.drop(['score'], axis=1)

    # Get column names
    X_column_names = experiments_X_df.columns

    # Convert to numpy
    experiments_X = experiments_X_df.values
    experiments_y = experiments_results[['score']].values

    # Create an XGBoost model tuned with the experiments data
    try:
        xgb_experiments_model
        # Tune hyperparameters every once in a while
        # if iteration % 7 == 6:
        #     xgb_experiments_model = get_xgboost_model(experiments_X, experiments_y)
    except:
        xgb_experiments_model = get_xgboost_model(experiments_X, experiments_y)

    # Fit the model
    xgb_experiments_model.fit(experiments_X_df, experiments_y)

    # Extract shap values
    explainer = shap.TreeExplainer(xgb_experiments_model)
    shap_values = explainer.shap_values(experiments_X_df)

    # Shap as dataframe
    shap_values_of_experiments = pd.DataFrame(shap_values, columns=X_column_names)
    shap_values_of_experiments['score'] = experiments_y

    # Function to support analysis
    def find_significance_from_experiments_results(importance_threshold=0.05, max_toggles_to_lock_per_series=5):
        temp_df = shap_values_of_experiments.drop(['score'], axis=1).copy()
        for i in range(0, len(shap_values_of_experiments.index)):
            for j in range(0, len(shap_values_of_experiments.columns)):
                if not experiments_results.iloc[i, j]:
                    temp_df.iloc[i, j] = -1 * shap_values_of_experiments.iloc[i, j]
        temp_df = temp_df.sum().sort_values()
        options_to_set_to_false = temp_df[temp_df > 0]
        options_to_set_to_true = temp_df[temp_df < 0]    
        sum_value = (options_to_set_to_false.sum() + abs(options_to_set_to_true.sum()))
        options_to_set_to_false = options_to_set_to_false / sum_value
        options_to_set_to_true = abs(options_to_set_to_true) / sum_value
        options_to_set_to_false = options_to_set_to_false[options_to_set_to_false > importance_threshold].sort_values(ascending=False)
        options_to_set_to_true = options_to_set_to_true[options_to_set_to_true > importance_threshold]
        return options_to_set_to_false[0:max_toggles_to_lock_per_series], options_to_set_to_true[0:max_toggles_to_lock_per_series]

    # Call function
    options_to_set_to_false, options_to_set_to_true = find_significance_from_experiments_results()

    # Make the set to true DF
    options_to_set_to_true_df = pd.DataFrame()
    transformation, value = None, None
    try:
        transformation_and_value = options_to_set_to_true.keys()
    except:
        transformation, value = [], []
    if len(transformation_and_value) > 0:
        options_to_set_to_true_df["transformation"] = [x.split("__")[0] for x in transformation_and_value]
        options_to_set_to_true_df["value"] = [x.split("__")[1] for x in transformation_and_value]
    else:
        options_to_set_to_true_df["transformation"] = []
        options_to_set_to_true_df["value"] = []
    options_to_set_to_true_df["significance"] = options_to_set_to_true.values

    # Make the false DF
    options_to_set_to_false_df = pd.DataFrame()
    transformation, value = None, None
    try:
        transformation_and_value = options_to_set_to_false.keys()
    except:
        transformation, value = [], []
    if len(transformation_and_value) > 0:
        options_to_set_to_false_df["transformation"] = [x.split("__")[0] for x in transformation_and_value]
        options_to_set_to_false_df["value"] = [x.split("__")[1] for x in transformation_and_value]
    else:
        options_to_set_to_false_df["transformation"] = []
        options_to_set_to_false_df["value"] = []
    options_to_set_to_false_df["significance"] = options_to_set_to_false.values

    # Reset updates
    updates = 0
    
    # Set to True
    for index, row in options_to_set_to_true_df.iterrows():
        if param_distributions[row['transformation']][int(row['value'])] == None:
            updates += 1
        param_distributions[row['transformation']][int(row['value'])] = True

    # Set to False
    for index, row in options_to_set_to_false_df.iterrows():
        if param_distributions[row['transformation']][int(row['value'])] == None:
            updates += 1        
        param_distributions[row['transformation']][int(row['value'])] = False        

    # End early if there is nothing to tune
    print("Updates:", updates)
    if updates == 0:
        break
    

print("Done")
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]/Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
#   2%|▏         | 2/100 [00:00<00:06, 16.24it/s]/Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/preprocessing/_discretization.py:161: UserWarning: Feature 0 is constant and will be replaced with 0.
#   "replaced with 0." % jj)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/preprocessing/_discretization.py:161: UserWarning: Feature 0 is constant and will be replaced with 0.
#   "replaced with 0." % jj)
#   4%|▍         | 4/100 [00:00<00:06, 15.94it/s]/Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
#   6%|▌         | 6/100 [00:00<00:05, 15.95it/s]/Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/preprocessing/_discretization.py:161: UserWarning: Feature 0 is constant and will be replaced with 0.
#   "replaced with 0." % jj)
#   8%|▊         | 8/100 [00:00<00:05, 16.34it/s]/Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/preprocessing/_discretization.py:161: UserWarning: Feature 0 is constant and will be replaced with 0.
#   "replaced with 0." % jj)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
#  10%|█         | 10/100 [00:00<00:05, 15.74it/s]/Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/preprocessing/_discretization.py:161: UserWarning: Feature 0 is constant and will be replaced with 0.
#   "replaced with 0." % jj)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/preprocessing/_discretization.py:161: UserWarning: Feature 0 is constant and will be replaced with 0.
#   "replaced with 0." % jj)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/preprocessing/_discretization.py:161: UserWarning: Feature 0 is constant and will be replaced with 0.
#   "replaced with 0." % jj)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/preprocessing/_discretization.py:161: UserWarning: Feature 0 is constant and will be replaced with 0.
#   "replaced with 0." % jj)
#  12%|█▏        | 12/100 [00:00<00:05, 15.69it/s]/Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/preprocessing/_discretization.py:161: UserWarning: Feature 0 is constant and will be replaced with 0.
#   "replaced with 0." % jj)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
#  14%|█▍        | 14/100 [00:00<00:05, 15.88it/s]/Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/preprocessing/_discretization.py:161: UserWarning: Feature 0 is constant and will be replaced with 0.
#   "replaced with 0." % jj)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
#  16%|█▌        | 16/100 [00:01<00:05, 15.58it/s]/Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
#  18%|█▊        | 18/100 [00:01<00:05, 15.92it/s]/Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
#  20%|██        | 20/100 [00:01<00:05, 15.95it/s]/Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/preprocessing/_discretization.py:161: UserWarning: Feature 0 is constant and will be replaced with 0.
#   "replaced with 0." % jj)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/preprocessing/_discretization.py:161: UserWarning: Feature 0 is constant and will be replaced with 0.
#   "replaced with 0." % jj)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
#  22%|██▏       | 22/100 [00:01<00:04, 15.79it/s]/Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
#  24%|██▍       | 24/100 [00:01<00:04, 15.97it/s]/Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
#  26%|██▌       | 26/100 [00:01<00:04, 16.48it/s]/Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/preprocessing/_discretization.py:161: UserWarning: Feature 0 is constant and will be replaced with 0.
#   "replaced with 0." % jj)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
#  28%|██▊       | 28/100 [00:01<00:04, 16.49it/s]/Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
#  30%|███       | 30/100 [00:01<00:04, 16.64it/s]/Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/preprocessing/_discretization.py:161: UserWarning: Feature 0 is constant and will be replaced with 0.
#   "replaced with 0." % jj)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
#  32%|███▏      | 32/100 [00:01<00:04, 16.58it/s]/Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
#  34%|███▍      | 34/100 [00:02<00:04, 16.40it/s]/Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/preprocessing/_discretization.py:161: UserWarning: Feature 0 is constant and will be replaced with 0.
#   "replaced with 0." % jj)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/preprocessing/_discretization.py:161: UserWarning: Feature 0 is constant and will be replaced with 0.
#   "replaced with 0." % jj)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
#  36%|███▌      | 36/100 [00:02<00:03, 16.16it/s]/Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
#  38%|███▊      | 38/100 [00:02<00:03, 15.98it/s]/Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/preprocessing/_discretization.py:161: UserWarning: Feature 0 is constant and will be replaced with 0.
#   "replaced with 0." % jj)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
#  40%|████      | 40/100 [00:02<00:03, 16.30it/s]/Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/preprocessing/_discretization.py:161: UserWarning: Feature 0 is constant and will be replaced with 0.
#   "replaced with 0." % jj)
#  42%|████▏     | 42/100 [00:02<00:03, 15.77it/s]/Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
#  44%|████▍     | 44/100 [00:02<00:03, 15.71it/s]/Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/preprocessing/_discretization.py:161: UserWarning: Feature 0 is constant and will be replaced with 0.
#   "replaced with 0." % jj)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/preprocessing/_discretization.py:161: UserWarning: Feature 0 is constant and will be replaced with 0.
#   "replaced with 0." % jj)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
#  46%|████▌     | 46/100 [00:02<00:03, 15.32it/s]/Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/preprocessing/_discretization.py:161: UserWarning: Feature 0 is constant and will be replaced with 0.
#   "replaced with 0." % jj)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
#  48%|████▊     | 48/100 [00:03<00:03, 15.80it/s]/Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/preprocessing/_discretization.py:161: UserWarning: Feature 0 is constant and will be replaced with 0.
#   "replaced with 0." % jj)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# ...
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
#  82%|████████▏ | 82/100 [00:05<00:01, 15.60it/s]/Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/preprocessing/_discretization.py:161: UserWarning: Feature 0 is constant and will be replaced with 0.
#   "replaced with 0." % jj)
#  84%|████████▍ | 84/100 [00:05<00:01, 15.79it/s]/Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/preprocessing/_discretization.py:161: UserWarning: Feature 0 is constant and will be replaced with 0.
#   "replaced with 0." % jj)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
#  86%|████████▌ | 86/100 [00:05<00:00, 15.84it/s]/Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/preprocessing/_discretization.py:161: UserWarning: Feature 0 is constant and will be replaced with 0.
#   "replaced with 0." % jj)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/preprocessing/_discretization.py:161: UserWarning: Feature 0 is constant and will be replaced with 0.
#   "replaced with 0." % jj)
#  88%|████████▊ | 88/100 [00:05<00:00, 15.65it/s]/Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
#  90%|█████████ | 90/100 [00:05<00:00, 15.95it/s]/Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/preprocessing/_discretization.py:161: UserWarning: Feature 0 is constant and will be replaced with 0.
#   "replaced with 0." % jj)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/preprocessing/_discretization.py:161: UserWarning: Feature 0 is constant and will be replaced with 0.
#   "replaced with 0." % jj)
#  92%|█████████▏| 92/100 [00:05<00:00, 16.31it/s]/Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/preprocessing/_discretization.py:161: UserWarning: Feature 0 is constant and will be replaced with 0.
#   "replaced with 0." % jj)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
#  94%|█████████▍| 94/100 [00:05<00:00, 16.38it/s]/Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/preprocessing/_discretization.py:161: UserWarning: Feature 0 is constant and will be replaced with 0.
#   "replaced with 0." % jj)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/preprocessing/_discretization.py:161: UserWarning: Feature 0 is constant and will be replaced with 0.
#   "replaced with 0." % jj)
#  96%|█████████▌| 96/100 [00:05<00:00, 16.18it/s]/Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/preprocessing/_discretization.py:161: UserWarning: Feature 0 is constant and will be replaced with 0.
#   "replaced with 0." % jj)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
#  98%|█████████▊| 98/100 [00:06<00:00, 15.47it/s]/Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/preprocessing/_discretization.py:161: UserWarning: Feature 0 is constant and will be replaced with 0.
#   "replaced with 0." % jj)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/preprocessing/_discretization.py:161: UserWarning: Feature 0 is constant and will be replaced with 0.
#   "replaced with 0." % jj)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# /Users/petermyers/Desktop/Code/commons/venv/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return_n_iter=True)
# 100%|██████████| 100/100 [00:06<00:00, 15.76it/s]
# Updates: 0
# Done

# %% [markdown]
# ## Final Results

# %%
experiments_results
# Out:
#      standard_scaler__0  standard_scaler__1  standard_scaler__2  \
# 0                 False               False                True
# 1                  True                True                True
# 2                  True               False               False
# 3                 False               False               False
# 4                  True                True                True
# 5                 False               False               False
# 6                 False                True               False
# 7                 False                True               False
# 8                 False                True               False
# 9                 False                True                True
# 10                False                True                True
# 11                False               False                True
# 12                 True                True               False
# 13                 True               False               False
# 14                False               False               False
# 15                 True                True                True
# 16                 True               False                True
# 17                 True                True                True
# 18                 True                True                True
# 19                False                True                True
# 20                False               False               False
# 21                False               False                True
# 22                 True               False               False
# 23                 True               False                True
# 24                False                True                True
# 25                 True                True               False
# 26                 True                True               False
# 27                False                True                True
# 28                False                True                True
# 29                 True                True               False
# ..                  ...                 ...                 ...
# 170                True               False                True
# 171               False               False               False
# 172               False               False                True
# 173                True                True                True
# 174                True               False                True
# 175                True                True               False
# 176                True               False                True
# 177               False                True                True
# 178               False               False               False
# 179                True                True               False
# 180               False                True               False
# 181                True               False                True
# 182                True                True               False
# 183                True               False               False
# 184               False               False                True
# 185               False                True                True
# 186               False               False               False
# 187                True                True               False
# 188               False               False                True
# 189                True               False               False
# 190                True               False               False
# 191                True                True               False
# 192               False                True               False
# 193                True                True               False
# 194                True               False               False
# 195                True                True               False
# 196                True               False               False
# 197               False               False               False
# 198                True                True               False
# 199                True               False                True
#
#      standard_scaler__3  standard_scaler__4  standard_scaler__5  \
# 0                  True               False               False
# 1                  True                True               False
# 2                  True                True                True
# 3                 False                True               False
# 4                 False                True               False
# 5                  True               False               False
# 6                 False               False               False
# 7                 False                True               False
# 8                 False                True                True
# 9                 False                True               False
# 10                False                True               False
# 11                False               False               False
# 12                False               False                True
# 13                False               False               False
# 14                 True               False               False
# 15                False               False               False
# 16                False                True               False
# 17                False               False               False
# 18                 True                True               False
# 19                 True                True                True
# 20                False               False                True
# 21                False                True               False
# 22                False                True               False
# 23                 True                True                True
# 24                 True               False                True
# 25                False                True               False
# 26                 True                True                True
# 27                False               False               False
# 28                False                True                True
# 29                 True                True                True
# ..                  ...                 ...                 ...
# 170                True               False               False
# 171               False               False               False
# 172               False               False               False
# 173               False               False               False
# 174                True               False               False
# 175                True               False               False
# 176                True               False               False
# 177                True               False               False
# 178                True               False               False
# 179               False               False               False
# 180               False               False               False
# 181               False               False               False
# 182               False               False               False
# 183               False               False               False
# 184                True               False               False
# 185                True               False               False
# 186               False               False               False
# 187               False               False               False
# 188               False               False               False
# 189               False               False               False
# 190               False               False               False
# 191               False               False               False
# 192               False               False               False
# 193                True               False               False
# 194               False               False               False
# 195               False               False               False
# 196               False               False               False
# 197                True               False               False
# 198               False               False               False
# 199                True               False               False
#
#      standard_scaler__6  standard_scaler__7  standard_scaler__8  \
# 0                  True                True               False
# 1                 False                True               False
# 2                 False                True               False
# 3                  True                True               False
# 4                  True                True               False
# 5                  True               False               False
# 6                 False               False                True
# 7                  True                True               False
# 8                 False                True               False
# 9                  True               False               False
# 10                 True               False                True
# 11                 True                True               False
# 12                 True               False               False
# 13                 True                True                True
# 14                False                True                True
# 15                False               False               False
# 16                 True               False                True
# 17                 True                True               False
# 18                False               False                True
# 19                False               False               False
# 20                 True               False               False
# 21                 True                True                True
# 22                False               False               False
# 23                 True                True               False
# 24                False                True               False
# 25                False               False                True
# 26                False               False                True
# 27                False               False               False
# 28                False                True                True
# 29                False                True                True
# ..                  ...                 ...                 ...
# 170               False               False                True
# 171               False               False               False
# 172               False               False                True
# 173               False               False               False
# 174               False               False               False
# 175               False               False                True
# 176                True               False                True
# 177                True               False                True
# 178               False               False               False
# 179               False               False                True
# 180                True               False                True
# 181                True               False                True
# 182               False               False               False
# 183               False               False               False
# 184                True               False               False
# 185                True               False                True
# 186                True               False               False
# 187                True               False               False
# 188               False               False               False
# 189               False               False                True
# 190               False               False                True
# 191                True               False                True
# 192               False               False               False
# 193                True               False                True
# 194                True               False               False
# 195               False               False               False
# 196                True               False               False
# 197                True               False               False
# 198               False               False               False
# 199               False               False                True
#
#      standard_scaler__9    ...      binarizer__4  binarizer__5  binarizer__6  \
# 0                  True    ...              True          True          True
# 1                  True    ...              True          True         False
# 2                 False    ...             False          True         False
# 3                  True    ...              True          True          True
# 4                  True    ...             False          True          True
# 5                 False    ...              True          True         False
# 6                  True    ...             False          True          True
# 7                 False    ...              True         False          True
# 8                  True    ...             False          True         False
# 9                 False    ...              True          True         False
# 10                 True    ...              True          True          True
# 11                False    ...              True          True         False
# 12                 True    ...              True          True          True
# 13                 True    ...              True          True          True
# 14                 True    ...             False          True          True
# 15                 True    ...             False          True         False
# 16                 True    ...              True          True          True
# 17                False    ...              True          True         False
# 18                 True    ...             False          True          True
# 19                False    ...             False          True          True
# 20                False    ...              True          True          True
# 21                False    ...              True         False          True
# 22                False    ...              True          True         False
# 23                False    ...              True         False         False
# 24                False    ...              True          True          True
# 25                False    ...              True         False          True
# 26                False    ...              True          True          True
# 27                False    ...             False          True         False
# 28                False    ...              True          True         False
# 29                False    ...             False          True         False
# ..                  ...    ...               ...           ...           ...
# 170                True    ...             False         False          True
# 171                True    ...             False         False         False
# 172                True    ...             False         False         False
# 173                True    ...             False         False          True
# 174                True    ...             False         False          True
# 175                True    ...             False         False         False
# 176               False    ...             False         False         False
# 177               False    ...             False         False          True
# 178               False    ...             False         False         False
# 179               False    ...             False         False          True
# 180               False    ...             False         False         False
# 181                True    ...             False         False         False
# 182               False    ...             False         False          True
# 183               False    ...             False         False         False
# 184                True    ...             False         False         False
# 185                True    ...             False         False         False
# 186                True    ...             False         False         False
# 187               False    ...             False         False         False
# 188               False    ...             False         False         False
# 189               False    ...             False         False         False
# 190               False    ...             False         False          True
# 191                True    ...             False         False         False
# 192               False    ...             False         False         False
# 193                True    ...             False         False         False
# 194                True    ...             False         False          True
# 195               False    ...             False         False          True
# 196                True    ...             False         False          True
# 197                True    ...             False         False         False
# 198                True    ...             False         False         False
# 199                True    ...             False         False          True
#
#      binarizer__7  binarizer__8  binarizer__9  binarizer__10  binarizer__11  \
# 0           False          True          True           True           True
# 1            True         False         False           True          False
# 2           False         False         False           True          False
# 3            True         False          True           True          False
# 4            True         False          True          False          False
# 5            True          True          True           True           True
# 6            True         False          True           True           True
# 7           False         False         False          False           True
# 8            True         False          True           True          False
# 9            True         False         False           True           True
# 10           True          True          True           True          False
# 11           True          True         False          False          False
# 12           True          True         False          False          False
# 13           True          True          True           True          False
# 14           True          True          True           True           True
# 15           True         False         False           True          False
# 16          False         False          True           True          False
# 17           True          True          True          False           True
# 18           True         False          True          False          False
# 19          False          True         False           True          False
# 20          False         False         False          False          False
# 21           True         False          True           True           True
# 22           True         False         False          False          False
# 23           True         False          True           True          False
# 24          False          True          True           True           True
# 25           True          True          True          False           True
# 26          False          True          True          False          False
# 27           True          True         False           True           True
# 28          False         False         False          False          False
# 29          False          True         False          False          False
# ..            ...           ...           ...            ...            ...
# 170         False         False          True           True          False
# 171         False         False         False           True          False
# 172         False          True          True          False          False
# 173         False          True          True           True           True
# 174         False          True         False          False          False
# 175         False         False         False           True          False
# 176         False          True         False          False          False
# 177         False         False         False           True          False
# 178         False          True         False           True           True
# 179         False         False          True           True           True
# 180         False          True          True           True          False
# 181         False          True         False          False          False
# 182         False          True         False          False          False
# 183         False          True         False           True          False
# 184         False          True          True          False          False
# 185         False          True          True           True          False
# 186         False         False         False           True           True
# 187         False          True          True          False           True
# 188         False         False         False           True          False
# 189         False          True          True           True          False
# 190         False         False          True           True           True
# 191         False          True         False          False           True
# 192         False         False          True          False          False
# 193         False         False         False           True          False
# 194         False          True         False           True          False
# 195         False          True         False          False          False
# 196         False         False          True          False          False
# 197         False          True         False          False          False
# 198         False         False         False           True           True
# 199         False          True         False          False           True
#
#      binarizer__12      score
# 0            False  30.895571
# 1             True  27.808199
# 2            False  27.588948
# 3            False  27.221573
# 4            False  27.176431
# 5            False  27.111820
# 6            False  27.083753
# 7            False  26.036836
# 8             True  25.868785
# 9            False  25.571401
# 10            True  25.523317
# 11           False  25.352742
# 12           False  25.299306
# 13            True  24.862878
# 14            True  24.595699
# 15           False  24.577830
# 16           False  24.042806
# 17           False  23.830877
# 18           False  23.814710
# 19            True  23.705876
# 20           False  23.225754
# 21           False  22.718981
# 22           False  22.636517
# 23           False  22.539804
# 24           False  22.394193
# 25            True  22.321934
# 26            True  22.197214
# 27            True  22.169315
# 28            True  21.878334
# 29           False  21.861456
# ..             ...        ...
# 170           True   6.534223
# 171           True   6.427661
# 172           True   6.382839
# 173          False   6.338728
# 174           True   6.326940
# 175           True   6.302369
# 176           True   6.276590
# 177           True   6.271175
# 178           True   6.266429
# 179           True   6.217053
# 180          False   6.168557
# 181           True   6.136688
# 182          False   6.136287
# 183           True   6.131936
# 184           True   6.080095
# 185           True   6.051494
# 186           True   6.022815
# 187           True   5.952563
# 188          False   5.902186
# 189           True   5.898865
# 190          False   5.861303
# 191           True   5.829616
# 192          False   5.769517
# 193           True   5.736806
# 194          False   5.719676
# 195           True   5.658398
# 196           True   5.634820
# 197          False   5.605104
# 198           True   5.562932
# 199           True   5.523703
#
# [200 rows x 79 columns]
