# %% [markdown]
# ## Imports
# - Place %%pycodestyle at the top of any cell to check python syntax

# %%
# %load_ext pycodestyle_magic
# %load_ext autoreload
# %autoreload 2

# Common imports
import pandas as pd
import numpy as np
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
import shap

# Import from my GitHub
from getxgboostmodel.getxgboostmodel import get_xgboost_model
from randomizedgridsearch.randomizedgridsearch import RandomizedGridSearch
from transformers.transformers import *

import sys

if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")
# Out:
# The pycodestyle_magic extension is already loaded. To reload it, use:
#   %reload_ext pycodestyle_magic
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Initialize

# %%
# Example dataset
boston_data = load_boston()

# Extract pandas dataframe and target
X = pd.DataFrame(boston_data['data']).copy().values
y = pd.DataFrame(boston_data['target']).copy().values

# Train/test split
train_X, test_X, train_y, test_y = train_test_split(
    X, y, test_size=0.20, random_state=42)
train_X, test_X = train_X, test_X
train_y, test_y = train_y.reshape(-1, 1), test_y.reshape(-1, 1)

# An okay model fit to the data
try:
    xgb_model
except:
    xgb_model = get_xgboost_model(train_X, train_y)

# Pipeline
pipe = Pipeline([('standard_scaler', StandardScalerTransform()),
                 ('min_max_scaler', MinMaxScalerTransform()),
                 ('binarizer', BinarizerTransform()), 
                 ('k_bins_discretizer', KBinsDiscretizerTransform()),
                 ('k_bins_discretizer2', KBinsDiscretizerTransform2()),
                 ('k_bins_discretizer3', KBinsDiscretizerTransform3()),
                 ('kernel_centerer', KernelCentererTransform())
                 ('model', xgb_model)])

# Find the number of features
num_features = train_X.shape[1]

# Testing with these indices
indices = list(range(num_features))

# Scalers
scaler_values = [0.05]*num_features

# Possible configurations [None, True, or False] - None means not decided yet
param_distributions = {
    'standard_scaler': scaler_values,
    'min_max_scaler': scaler_values,
    'binarizer': scaler_values,
    'k_bins_discretizer': scaler_values,
    'k_bins_discretizer2': scaler_values,
    'k_bins_discretizer3': scaler_values, 
    'kernel_centerer': scaler_values,     
}

experiments_results = pd.DataFrame()

# %% [markdown]
# ## Run the Experiments

# %%
for iteration in range(20):
    # Randomly search the space n_iter times
    experiments_results_temp = RandomizedGridSearch(
        n_experiments=100,
        pipe=pipe,
        param_distributions=param_distributions,
        train_X=train_X,
        train_y=train_y,
        test_X=test_X,
        test_y=test_y,
        scoring='neg_mean_squared_error')
    
    # Append to experiment results
    experiments_results = experiments_results.append(experiments_results_temp, ignore_index=True)
    
    # Ignore past data
    # experiments_results = experiments_results_temp

    # Drop score
    experiments_X_df = experiments_results.drop(['score'], axis=1)

    # Get column names
    X_column_names = experiments_X_df.columns

    # Convert to numpy
    experiments_X = experiments_X_df.values
    experiments_y = experiments_results[['score']].values

    # Create an XGBoost model tuned with the experiments data
    try:
        xgb_experiments_model
        # Tune hyperparameters every once in a while
        # if iteration % 7 == 6:
        #     xgb_experiments_model = get_xgboost_model(experiments_X, experiments_y)
    except:
        xgb_experiments_model = get_xgboost_model(experiments_X, experiments_y)

    # Fit the model
    xgb_experiments_model.fit(experiments_X_df, experiments_y)

    # Extract shap values
    explainer = shap.TreeExplainer(xgb_experiments_model)
    shap_values = explainer.shap_values(experiments_X_df)

    # Shap as dataframe
    shap_values_of_experiments = pd.DataFrame(shap_values, columns=X_column_names)
    shap_values_of_experiments['score'] = experiments_y

    # Function to support analysis
    def find_significance_from_experiments_results(importance_threshold=0.001, max_toggles_to_lock_per_series=5):
        temp_df = shap_values_of_experiments.drop(['score'], axis=1).copy()
        for i in range(0, len(shap_values_of_experiments.index)):
            for j in range(0, len(shap_values_of_experiments.columns)):
                if not experiments_results.iloc[i, j]:
                    temp_df.iloc[i, j] = -1 * shap_values_of_experiments.iloc[i, j]
        temp_df = temp_df.sum().sort_values()
        options_to_set_to_false = temp_df[temp_df > 0]
        options_to_set_to_true = temp_df[temp_df < 0]    
        sum_value = (options_to_set_to_false.sum() + abs(options_to_set_to_true.sum()))
        options_to_set_to_false = options_to_set_to_false / sum_value
        options_to_set_to_true = abs(options_to_set_to_true) / sum_value
        options_to_set_to_false = options_to_set_to_false[options_to_set_to_false > importance_threshold].sort_values(ascending=False)
        options_to_set_to_true = options_to_set_to_true[options_to_set_to_true > importance_threshold]
        return options_to_set_to_false[0:max_toggles_to_lock_per_series], options_to_set_to_true[0:max_toggles_to_lock_per_series]

    # Call function
    options_to_set_to_false, options_to_set_to_true = find_significance_from_experiments_results()

    # Make the set to true DF
    options_to_set_to_true_df = pd.DataFrame()
    transformation, value = None, None
    try:
        transformation_and_value = options_to_set_to_true.keys()
    except:
        transformation, value = [], []
    if len(transformation_and_value) > 0:
        options_to_set_to_true_df["transformation"] = [x.split("__")[0] for x in transformation_and_value]
        options_to_set_to_true_df["value"] = [x.split("__")[1] for x in transformation_and_value]
    else:
        options_to_set_to_true_df["transformation"] = []
        options_to_set_to_true_df["value"] = []
    options_to_set_to_true_df["significance"] = options_to_set_to_true.values

    # Make the false DF
    options_to_set_to_false_df = pd.DataFrame()
    transformation, value = None, None
    try:
        transformation_and_value = options_to_set_to_false.keys()
    except:
        transformation, value = [], []
    if len(transformation_and_value) > 0:
        options_to_set_to_false_df["transformation"] = [x.split("__")[0] for x in transformation_and_value]
        options_to_set_to_false_df["value"] = [x.split("__")[1] for x in transformation_and_value]
    else:
        options_to_set_to_false_df["transformation"] = []
        options_to_set_to_false_df["value"] = []
    options_to_set_to_false_df["significance"] = options_to_set_to_false.values

    # Reset updates
    updates = 0
    
    # Set to True
    for index, row in options_to_set_to_true_df.iterrows():            
        if param_distributions[row['transformation']][int(row['value'])] < 1.0:
            updates += 1
        param_distributions[row['transformation']][int(row['value'])] *= 2.0        
        if param_distributions[row['transformation']][int(row['value'])] >= 1.0:
            param_distributions[row['transformation']][int(row['value'])] = 1.0        
        

    for index, row in options_to_set_to_false_df.iterrows():
        if param_distributions[row['transformation']][int(row['value'])] > 0.01:
            updates += 1        
        param_distributions[row['transformation']][int(row['value'])] *= 0.5
        if param_distributions[row['transformation']][int(row['value'])] <= 0.01:
            param_distributions[row['transformation']][int(row['value'])] = 0.01

    # End early if there is nothing to tune
    print("Updates:", updates)
    if updates == 0:
        break
    
print("Done")
# Out:
# 100%|██████████| 100/100 [00:04<00:00, 19.94it/s]
#   2%|▏         | 2/100 [00:00<00:05, 19.46it/s]
# Updates: 10
# 100%|██████████| 100/100 [00:05<00:00, 19.59it/s]
#   2%|▏         | 2/100 [00:00<00:05, 18.96it/s]
# Updates: 7
# 100%|██████████| 100/100 [00:05<00:00, 18.67it/s]
#   2%|▏         | 2/100 [00:00<00:05, 18.14it/s]
# Updates: 4
# 100%|██████████| 100/100 [00:05<00:00, 18.66it/s]
#   2%|▏         | 2/100 [00:00<00:05, 16.90it/s]
# Updates: 7
# 100%|██████████| 100/100 [00:05<00:00, 18.07it/s]
#   2%|▏         | 2/100 [00:00<00:05, 18.49it/s]
# Updates: 6
# 100%|██████████| 100/100 [00:05<00:00, 18.02it/s]
#   2%|▏         | 2/100 [00:00<00:05, 18.78it/s]
# Updates: 5
# 100%|██████████| 100/100 [00:05<00:00, 18.38it/s]
#   2%|▏         | 2/100 [00:00<00:05, 17.66it/s]
# Updates: 3
# 100%|██████████| 100/100 [00:05<00:00, 18.08it/s]
#   2%|▏         | 2/100 [00:00<00:05, 17.93it/s]
# Updates: 2
# 100%|██████████| 100/100 [00:05<00:00, 17.48it/s]
#   2%|▏         | 2/100 [00:00<00:05, 18.26it/s]
# Updates: 3
# 100%|██████████| 100/100 [00:05<00:00, 17.22it/s]
#   2%|▏         | 2/100 [00:00<00:05, 18.25it/s]
# Updates: 3
# 100%|██████████| 100/100 [00:05<00:00, 17.32it/s]
#   2%|▏         | 2/100 [00:00<00:05, 16.79it/s]
# Updates: 3
# 100%|██████████| 100/100 [00:06<00:00, 14.17it/s]
#   2%|▏         | 2/100 [00:00<00:05, 18.26it/s]
# Updates: 2
# 100%|██████████| 100/100 [00:05<00:00, 15.54it/s]
#   2%|▏         | 2/100 [00:00<00:05, 17.81it/s]
# Updates: 3
# 100%|██████████| 100/100 [00:05<00:00, 17.49it/s]
#   2%|▏         | 2/100 [00:00<00:05, 18.77it/s]
# Updates: 3
# 100%|██████████| 100/100 [00:05<00:00, 17.36it/s]
#   2%|▏         | 2/100 [00:00<00:05, 19.03it/s]
# Updates: 3
# 100%|██████████| 100/100 [00:05<00:00, 17.26it/s]
#   2%|▏         | 2/100 [00:00<00:05, 17.69it/s]
# Updates: 3
# 100%|██████████| 100/100 [00:05<00:00, 17.79it/s]
#   2%|▏         | 2/100 [00:00<00:05, 17.48it/s]
# Updates: 4
# 100%|██████████| 100/100 [00:05<00:00, 17.32it/s]
#   2%|▏         | 2/100 [00:00<00:05, 17.08it/s]
# Updates: 2
# 100%|██████████| 100/100 [00:05<00:00, 17.62it/s]
#   2%|▏         | 2/100 [00:00<00:05, 17.46it/s]
# Updates: 2
# 100%|██████████| 100/100 [00:05<00:00, 17.48it/s]
# Updates: 3
# Done

# %%
param_distributions
# Out:
# {'standard_scaler': [0.1,
#   0.05,
#   0.1,
#   0.05,
#   0.1,
#   0.01,
#   0.05,
#   0.01,
#   0.05,
#   0.4,
#   0.1,
#   0.05,
#   0.2],
#  'min_max_scaler': [0.1,
#   0.05,
#   0.1,
#   0.05,
#   0.1,
#   0.01,
#   0.05,
#   0.01,
#   0.05,
#   0.4,
#   0.1,
#   0.05,
#   0.2],
#  'binarizer': [0.1,
#   0.05,
#   0.1,
#   0.05,
#   0.1,
#   0.01,
#   0.05,
#   0.01,
#   0.05,
#   0.4,
#   0.1,
#   0.05,
#   0.2],
#  'k_bins_discretizer': [0.1,
#   0.05,
#   0.1,
#   0.05,
#   0.1,
#   0.01,
#   0.05,
#   0.01,
#   0.05,
#   0.4,
#   0.1,
#   0.05,
#   0.2],
#  'k_bins_discretizer2': [0.1,
#   0.05,
#   0.1,
#   0.05,
#   0.1,
#   0.01,
#   0.05,
#   0.01,
#   0.05,
#   0.4,
#   0.1,
#   0.05,
#   0.2],
#  'k_bins_discretizer3': [0.1,
#   0.05,
#   0.1,
#   0.05,
#   0.1,
#   0.01,
#   0.05,
#   0.01,
#   0.05,
#   0.4,
#   0.1,
#   0.05,
#   0.2]}

# %% [markdown]
# ## Final Results

# %%
pd.set_option('display.max_columns', 500)

experiments_results.sort_values(by='score')
# Out:
#       standard_scaler__0  standard_scaler__1  standard_scaler__2  \
# 1799               False                True               False
# 699                False               False               False
# 1099               False               False                True
# 999                False               False               False
# 799                False               False               False
# 1098               False               False               False
# 1798               False               False               False
# 1299               False               False               False
# 1699               False               False               False
# 1698               False               False               False
# 899                False               False               False
# 1899                True               False               False
# 1999               False               False               False
# 1697               False               False                True
# 1399               False               False                True
# 1797               False               False               False
# 1599               False               False               False
# 1398                True               False               False
# 898                False                True                True
# 1796               False               False               False
# 1998               False               False               False
# 1696               False               False               False
# 1298               False               False               False
# 1499               False               False               False
# 1794               False               False               False
# 1795               False               False               False
# 1793               False               False               False
# 1695               False               False               False
# 1598               False                True                True
# 698                False               False               False
# ...                  ...                 ...                 ...
# 802                False               False                True
# 1001               False               False               False
# 8                  False               False               False
# 702                False               False                True
# 1800               False               False               False
# 801                False               False               False
# 1102               False               False               False
# 7                  False               False               False
# 200                False               False               False
# 300                False               False               False
# 1300               False               False               False
# 401                False               False               False
# 100                False               False               False
# 6                  False               False               False
# 1101               False               False               False
# 1000               False               False               False
# 5                  False               False               False
# 4                  False               False               False
# 3                  False               False               False
# 1400               False               False               False
# 800                False               False               False
# 2                  False               False               False
# 1                  False               False               False
# 701                False               False               False
# 900                False               False               False
# 1900               False               False               False
# 1100               False               False                True
# 400                False               False               False
# 0                  False               False               False
# 700                False                True                True
#
#       standard_scaler__3  standard_scaler__4  standard_scaler__5  \
# 1799                True               False               False
# 699                False               False               False
# 1099               False               False               False
# 999                False                True               False
# 799                False               False               False
# 1098               False               False               False
# 1798                True               False               False
# 1299                True               False               False
# 1699                True               False               False
# 1698                True               False               False
# 899                False               False               False
# 1899                True               False               False
# 1999                True               False               False
# 1697                True               False               False
# 1399               False               False               False
# 1797                True               False               False
# 1599               False               False               False
# 1398               False               False               False
# 898                False               False               False
# 1796                True               False               False
# 1998                True               False               False
# 1696               False               False                True
# 1298               False               False               False
# 1499               False               False               False
# 1794                True               False               False
# 1795                True               False               False
# 1793                True               False               False
# 1695                True               False               False
# 1598               False               False               False
# 698                False               False               False
# ...                  ...                 ...                 ...
# 802                False               False               False
# 1001               False               False               False
# 8                  False               False               False
# 702                False               False               False
# 1800                True               False               False
# 801                False               False               False
# 1102                True               False               False
# 7                  False               False               False
# 200                False               False               False
# 300                False               False               False
# 1300               False               False               False
# 401                False               False               False
# 100                False               False               False
# 6                  False               False               False
# 1101               False               False               False
# 1000               False               False               False
# 5                  False               False               False
# 4                  False               False               False
# 3                  False                True               False
# 1400               False               False               False
# 800                False               False               False
# 2                  False               False               False
# 1                  False               False               False
# 701                False               False               False
# 900                False               False               False
# 1900                True               False               False
# 1100               False               False               False
# 400                False               False               False
# 0                  False               False               False
# 700                False               False               False
#
#       standard_scaler__6  standard_scaler__7  standard_scaler__8  \
# 1799               False               False                True
# 699                False               False                True
# 1099               False               False                True
# 999                False               False                True
# 799                False               False                True
# 1098               False               False                True
# 1798               False               False                True
# 1299               False               False                True
# 1699               False               False                True
# 1698               False               False                True
# 899                False               False                True
# 1899               False               False                True
# 1999               False               False                True
# 1697               False               False                True
# 1399               False               False                True
# 1797               False               False                True
# 1599               False               False                True
# 1398               False               False                True
# 898                False               False                True
# 1796               False               False                True
# 1998               False               False                True
# 1696               False               False                True
# 1298               False               False                True
# 1499                True               False                True
# 1794               False               False                True
# 1795               False               False                True
# 1793               False               False                True
# 1695                True               False                True
# 1598               False               False                True
# 698                False               False                True
# ...                  ...                 ...                 ...
# 802                False               False                True
# 1001               False               False                True
# 8                  False               False                True
# 702                False               False                True
# 1800               False               False                True
# 801                False               False                True
# 1102               False               False                True
# 7                  False               False               False
# 200                False               False                True
# 300                False               False                True
# 1300               False               False                True
# 401                False               False                True
# 100                 True               False               False
# 6                  False               False               False
# 1101               False               False                True
# 1000               False               False                True
# 5                  False               False               False
# 4                   True               False               False
# 3                  False               False               False
# 1400               False               False                True
# 800                 True               False                True
# 2                  False               False               False
# 1                   True               False               False
# 701                False                True                True
# 900                False               False                True
# 1900               False                True                True
# 1100               False               False                True
# 400                False               False                True
# 0                  False               False               False
# 700                 True               False                True
#
#       standard_scaler__9  standard_scaler__10  standard_scaler__11  \
# 1799                True                False                 True
# 699                False                False                 True
# 1099                True                False                 True
# 999                False                False                 True
# 799                False                False                 True
# 1098               False                False                 True
# 1798                True                False                 True
# 1299                True                False                 True
# 1699                True                False                 True
# 1698                True                False                 True
# 899                False                False                 True
# 1899                True                False                 True
# 1999                True                False                 True
# 1697                True                False                 True
# 1399                True                False                 True
# 1797                True                False                 True
# 1599                True                False                 True
# 1398                True                False                 True
# 898                False                False                 True
# 1796                True                 True                 True
# 1998                True                False                 True
# 1696                True                False                 True
# 1298                True                False                 True
# 1499                True                False                 True
# 1794                True                False                 True
# 1795                True                False                 True
# 1793                True                False                 True
# 1695                True                False                 True
# 1598                True                False                 True
# 698                False                False                 True
# ...                  ...                  ...                  ...
# 802                 True                False                 True
# 1001                True                False                 True
# 8                  False                False                False
# 702                False                False                 True
# 1800                True                False                 True
# 801                False                False                 True
# 1102                True                False                 True
# 7                  False                False                False
# 200                False                False                False
# 300                False                False                False
# 1300                True                False                 True
# 401                False                False                False
# 100                 True                 True                False
# 6                  False                False                False
# 1101                True                False                 True
# 1000                True                False                 True
# 5                  False                False                False
# 4                  False                False                False
# 3                  False                False                False
# 1400                True                False                 True
# 800                False                False                 True
# 2                  False                False                False
# 1                  False                False                False
# 701                False                False                 True
# 900                False                False                 True
# 1900                True                False                 True
# 1100                True                False                 True
# 400                False                False                 True
# 0                  False                False                False
# 700                 True                False                 True
#
#       standard_scaler__12  min_max_scaler__0  min_max_scaler__1  \
# 1799                False              False              False
# 699                 False              False              False
# 1099                 True              False              False
# 999                 False              False              False
# 799                  True              False              False
# 1098                 True              False               True
# 1798                False              False               True
# 1299                 True              False              False
# 1699                False              False               True
# 1698                False              False              False
# 899                 False              False              False
# 1899                False              False              False
# 1999                 True              False              False
# 1697                False              False              False
# 1399                False              False              False
# 1797                 True              False              False
# 1599                 True              False              False
# 1398                False              False              False
# 898                 False              False              False
# 1796                 True              False              False
# 1998                False              False              False
# 1696                 True              False              False
# 1298                 True               True               True
# 1499                False              False              False
# 1794                False              False              False
# 1795                False              False              False
# 1793                 True              False              False
# 1695                False              False              False
# 1598                False              False              False
# 698                  True              False              False
# ...                   ...                ...                ...
# 802                  True              False              False
# 1001                False              False              False
# 8                   False              False              False
# 702                 False              False              False
# 1800                False              False              False
# 801                  True              False              False
# 1102                 True              False              False
# 7                   False              False              False
# 200                  True              False              False
# 300                  True              False              False
# 1300                 True              False              False
# 401                  True              False              False
# 100                  True              False              False
# 6                   False              False              False
# 1101                 True              False              False
# 1000                 True              False               True
# 5                   False              False              False
# 4                   False              False               True
# 3                   False              False              False
# 1400                 True              False               True
# 800                  True              False              False
# 2                   False              False              False
# 1                   False              False              False
# 701                  True              False              False
# 900                 False              False              False
# 1900                 True              False              False
# 1100                False              False              False
# 400                  True              False              False
# 0                   False              False               True
# 700                 False              False               True
#
#       min_max_scaler__2  min_max_scaler__3  min_max_scaler__4  \
# 1799              False               True              False
# 699                True              False              False
# 1099              False              False              False
# 999               False              False              False
# 799               False              False              False
# 1098               True              False              False
# 1798               True               True              False
# 1299              False              False              False
# 1699               True               True              False
# 1698              False               True              False
# 899               False               True              False
# 1899              False               True              False
# 1999              False               True              False
# 1697               True              False              False
# 1399              False              False              False
# 1797              False               True              False
# 1599              False              False              False
# 1398              False              False              False
# 898               False              False              False
# 1796               True               True              False
# 1998              False               True              False
# 1696               True               True              False
# 1298              False              False              False
# 1499              False              False              False
# 1794              False               True              False
# 1795              False               True              False
# 1793              False               True              False
# 1695              False               True              False
# 1598              False              False              False
# 698               False              False              False
# ...                 ...                ...                ...
# 802               False              False              False
# 1001              False              False              False
# 8                 False              False              False
# 702               False              False              False
# 1800              False               True              False
# 801                True              False              False
# 1102              False              False              False
# 7                 False               True              False
# 200               False              False              False
# 300               False              False              False
# 1300              False              False              False
# 401                True              False              False
# 100               False              False              False
# 6                 False               True              False
# 1101              False              False              False
# 1000              False              False              False
# 5                 False              False               True
# 4                 False              False              False
# 3                 False              False              False
# 1400              False               True               True
# 800                True               True              False
# 2                 False              False              False
# 1                 False               True              False
# 701               False              False              False
# 900                True              False              False
# 1900              False               True              False
# 1100              False              False              False
# 400               False              False              False
# 0                 False              False              False
# 700               False              False              False
#
#       min_max_scaler__5  min_max_scaler__6  min_max_scaler__7  \
# 1799              False              False              False
# 699               False              False              False
# 1099              False              False              False
# 999               False              False              False
# 799               False              False              False
# 1098              False              False              False
# 1798              False              False              False
# 1299              False              False              False
# 1699              False              False              False
# 1698              False              False              False
# 899               False               True              False
# 1899              False              False              False
# 1999              False              False              False
# 1697              False              False              False
# 1399              False              False              False
# 1797              False              False              False
# 1599              False              False              False
# 1398              False              False              False
# 898               False              False              False
# 1796              False              False              False
# 1998              False              False              False
# 1696              False              False              False
# 1298              False              False              False
# 1499              False              False              False
# 1794              False              False              False
# 1795              False              False              False
# 1793              False              False              False
# 1695              False              False              False
# 1598              False              False              False
# 698               False              False              False
# ...                 ...                ...                ...
# 802               False              False              False
# 1001              False              False              False
# 8                 False              False              False
# 702               False              False              False
# 1800              False              False              False
# 801               False              False              False
# 1102              False              False              False
# 7                  True              False              False
# 200               False              False              False
# 300               False              False              False
# 1300              False              False              False
# 401               False              False              False
# 100               False              False              False
# 6                 False              False              False
# 1101              False              False              False
# 1000              False               True              False
# 5                 False              False              False
# 4                  True              False              False
# 3                 False              False              False
# 1400              False              False              False
# 800               False              False              False
# 2                 False              False              False
# 1                 False               True              False
# 701               False              False              False
# 900               False              False              False
# 1900              False              False              False
# 1100              False              False              False
# 400               False               True              False
# 0                 False              False              False
# 700               False              False              False
#
#       min_max_scaler__8  min_max_scaler__9  min_max_scaler__10  \
# 1799               True               True               False
# 699                True               True               False
# 1099               True               True               False
# 999                True               True               False
# 799                True              False               False
# 1098               True              False               False
# 1798               True               True               False
# 1299               True               True                True
# 1699               True               True               False
# 1698               True               True               False
# 899                True              False                True
# 1899               True               True               False
# 1999               True               True               False
# 1697               True               True               False
# 1399               True               True               False
# 1797               True               True               False
# 1599               True               True               False
# 1398               True               True               False
# 898                True              False               False
# 1796               True               True               False
# 1998               True               True               False
# 1696               True               True               False
# 1298               True               True               False
# 1499               True               True               False
# 1794               True               True               False
# 1795               True               True               False
# 1793               True               True               False
# 1695               True               True               False
# 1598               True               True               False
# 698                True              False               False
# ...                 ...                ...                 ...
# 802                True              False               False
# 1001               True               True                True
# 8                 False              False               False
# 702                True               True               False
# 1800               True               True               False
# 801                True               True               False
# 1102               True               True               False
# 7                 False              False               False
# 200                True              False               False
# 300               False              False               False
# 1300               True               True               False
# 401                True              False               False
# 100               False              False               False
# 6                 False              False               False
# 1101               True               True               False
# 1000               True              False               False
# 5                 False              False               False
# 4                 False              False               False
# 3                 False              False               False
# 1400               True               True               False
# 800                True              False               False
# 2                 False               True               False
# 1                 False              False                True
# 701                True              False               False
# 900                True              False               False
# 1900               True               True               False
# 1100               True               True                True
# 400                True              False               False
# 0                 False              False               False
# 700                True               True               False
#
#       min_max_scaler__11  min_max_scaler__12  binarizer__0  binarizer__1  \
# 1799                True                True         False         False
# 699                 True                True         False         False
# 1099                True                True         False         False
# 999                 True                True         False         False
# 799                 True               False         False         False
# 1098                True                True         False         False
# 1798                True               False         False         False
# 1299                True               False         False         False
# 1699                True               False         False         False
# 1698                True               False         False         False
# 899                 True               False         False         False
# 1899                True                True         False         False
# 1999                True               False         False         False
# 1697                True                True         False         False
# 1399                True                True         False         False
# 1797                True                True         False         False
# 1599                True                True         False         False
# 1398                True               False         False         False
# 898                 True               False         False         False
# 1796                True               False         False         False
# 1998                True                True         False          True
# 1696                True                True         False          True
# 1298                True                True         False          True
# 1499                True               False         False         False
# 1794                True               False         False          True
# 1795                True               False         False         False
# 1793                True                True         False         False
# 1695                True               False         False         False
# 1598                True                True         False         False
# 698                 True               False         False         False
# ...                  ...                 ...           ...           ...
# 802                 True                True         False         False
# 1001                True               False         False         False
# 8                  False               False         False         False
# 702                 True                True         False         False
# 1800                True                True         False         False
# 801                 True               False         False         False
# 1102                True                True         False         False
# 7                  False                True         False         False
# 200                False               False         False         False
# 300                False               False         False          True
# 1300                True                True         False          True
# 401                False               False         False         False
# 100                False               False         False         False
# 6                  False               False         False         False
# 1101                True               False         False          True
# 1000                True               False         False         False
# 5                  False               False         False         False
# 4                  False               False         False         False
# 3                  False               False         False         False
# 1400                True                True         False         False
# 800                 True               False         False         False
# 2                  False               False         False         False
# 1                  False               False         False         False
# 701                 True               False         False         False
# 900                 True                True         False         False
# 1900                True               False          True         False
# 1100                True                True         False         False
# 400                False               False         False          True
# 0                  False               False         False         False
# 700                 True               False          True          True
#
#       binarizer__2  binarizer__3  binarizer__4  binarizer__5  binarizer__6  \
# 1799          True          True         False         False         False
# 699           True         False         False         False         False
# 1099          True         False         False         False         False
# 999          False         False         False         False         False
# 799          False         False         False         False         False
# 1098         False         False         False         False         False
# 1798          True          True         False         False         False
# 1299         False         False         False         False         False
# 1699         False         False         False         False         False
# 1698         False          True         False         False         False
# 899           True         False         False         False         False
# 1899         False          True         False         False         False
# 1999          True          True         False         False         False
# 1697         False          True         False         False         False
# 1399         False         False         False         False         False
# 1797         False          True         False         False         False
# 1599         False          True         False         False         False
# 1398         False         False         False         False         False
# 898          False         False         False         False         False
# 1796          True          True         False         False         False
# 1998          True          True         False         False         False
# 1696         False          True         False         False         False
# 1298          True         False         False         False         False
# 1499         False         False         False         False         False
# 1794          True          True         False         False         False
# 1795          True          True         False         False         False
# 1793          True          True         False         False         False
# 1695         False          True         False         False         False
# 1598         False          True         False         False         False
# 698          False         False         False         False         False
# ...            ...           ...           ...           ...           ...
# 802          False         False         False         False         False
# 1001         False         False          True         False         False
# 8            False         False         False          True         False
# 702          False         False         False          True         False
# 1800         False          True         False          True         False
# 801          False         False         False          True         False
# 1102         False         False         False          True         False
# 7            False         False         False          True         False
# 200          False         False          True         False         False
# 300           True          True         False         False         False
# 1300         False         False         False          True         False
# 401          False          True         False         False         False
# 100          False         False          True         False         False
# 6            False         False         False          True         False
# 1101         False         False         False         False          True
# 1000         False         False         False          True         False
# 5            False         False         False          True          True
# 4            False         False         False          True         False
# 3            False         False         False          True         False
# 1400         False         False         False          True         False
# 800          False         False         False          True         False
# 2            False         False         False          True         False
# 1            False         False         False          True         False
# 701          False         False         False          True          True
# 900          False         False         False          True         False
# 1900         False          True         False          True         False
# 1100         False         False         False          True         False
# 400          False         False         False         False         False
# 0             True         False         False          True         False
# 700          False         False         False          True         False
#
#       binarizer__7  binarizer__8  binarizer__9  binarizer__10  binarizer__11  \
# 1799         False          True          True          False           True
# 699          False          True         False          False           True
# 1099         False          True         False          False           True
# 999          False          True         False          False           True
# 799          False          True         False          False           True
# 1098         False          True         False           True           True
# 1798         False          True          True          False           True
# 1299         False          True          True          False           True
# 1699         False          True          True          False           True
# 1698         False          True          True          False           True
# 899          False          True         False          False           True
# 1899         False          True          True          False           True
# 1999         False          True          True          False           True
# 1697         False          True          True          False           True
# 1399         False          True          True          False           True
# 1797         False          True          True          False           True
# 1599         False          True          True          False           True
# 1398         False          True          True          False           True
# 898          False          True         False          False           True
# 1796         False          True          True          False           True
# 1998         False          True          True          False           True
# 1696         False          True          True          False           True
# 1298         False          True          True          False           True
# 1499         False          True          True          False           True
# 1794         False          True          True          False           True
# 1795         False          True          True          False           True
# 1793         False          True          True          False           True
# 1695         False          True          True          False           True
# 1598         False          True          True          False           True
# 698          False          True         False          False           True
# ...            ...           ...           ...            ...            ...
# 802          False          True         False          False           True
# 1001         False          True          True          False           True
# 8            False         False         False          False          False
# 702          False          True         False          False           True
# 1800         False          True          True          False           True
# 801          False          True          True          False           True
# 1102         False          True          True          False           True
# 7            False         False         False          False          False
# 200           True         False         False          False          False
# 300           True          True         False          False          False
# 1300          True          True          True          False           True
# 401          False          True         False          False          False
# 100          False         False         False           True          False
# 6            False         False         False          False          False
# 1101         False          True          True          False           True
# 1000         False          True          True          False           True
# 5            False         False         False          False          False
# 4            False         False          True          False          False
# 3            False         False         False          False          False
# 1400         False          True          True          False           True
# 800          False          True         False          False           True
# 2            False         False         False          False           True
# 1            False         False         False          False          False
# 701          False          True         False          False           True
# 900          False          True          True          False           True
# 1900         False          True          True          False           True
# 1100         False          True          True          False           True
# 400          False          True         False          False          False
# 0            False         False          True          False          False
# 700          False          True         False          False           True
#
#       binarizer__12  k_bins_discretizer__0  k_bins_discretizer__1  \
# 1799          False                  False                  False
# ...
# 200                    False                   False                   False
# 300                    False                   False                   False
# 1300                   False                   False                   False
# 401                    False                   False                   False
# 100                    False                   False                   False
# 6                      False                   False                   False
# 1101                    True                   False                   False
# 1000                   False                   False                   False
# 5                      False                   False                   False
# 4                      False                   False                   False
# 3                      False                   False                   False
# 1400                   False                   False                   False
# 800                    False                   False                   False
# 2                      False                   False                   False
# 1                      False                    True                   False
# 701                    False                   False                   False
# 900                    False                   False                   False
# 1900                   False                    True                   False
# 1100                   False                   False                   False
# 400                     True                   False                   False
# 0                      False                   False                    True
# 700                    False                   False                   False
#
#       k_bins_discretizer3__5  k_bins_discretizer3__6  k_bins_discretizer3__7  \
# 1799                   False                   False                   False
# 699                    False                   False                   False
# 1099                   False                   False                   False
# 999                    False                   False                   False
# 799                    False                   False                   False
# 1098                   False                   False                   False
# 1798                   False                   False                   False
# 1299                   False                   False                   False
# 1699                   False                   False                   False
# 1698                   False                   False                   False
# 899                    False                   False                   False
# 1899                   False                   False                   False
# 1999                   False                   False                   False
# 1697                   False                   False                   False
# 1399                   False                   False                   False
# 1797                   False                   False                   False
# 1599                   False                   False                   False
# 1398                   False                   False                   False
# 898                    False                    True                   False
# 1796                   False                   False                   False
# 1998                   False                   False                   False
# 1696                   False                   False                   False
# 1298                   False                   False                   False
# 1499                   False                   False                   False
# 1794                   False                   False                   False
# 1795                   False                   False                   False
# 1793                   False                   False                   False
# 1695                   False                   False                   False
# 1598                   False                   False                   False
# 698                    False                   False                   False
# ...                      ...                     ...                     ...
# 802                    False                   False                    True
# 1001                   False                   False                    True
# 8                      False                   False                   False
# 702                    False                   False                   False
# 1800                   False                   False                   False
# 801                    False                   False                   False
# 1102                   False                   False                   False
# 7                      False                   False                   False
# 200                    False                   False                   False
# 300                    False                   False                   False
# 1300                   False                   False                   False
# 401                    False                   False                   False
# 100                    False                   False                   False
# 6                      False                   False                   False
# 1101                   False                   False                   False
# 1000                   False                    True                   False
# 5                      False                   False                   False
# 4                      False                    True                   False
# 3                      False                   False                   False
# 1400                   False                   False                   False
# 800                    False                   False                   False
# 2                      False                   False                   False
# 1                      False                   False                   False
# 701                    False                   False                   False
# 900                    False                   False                   False
# 1900                   False                   False                   False
# 1100                   False                   False                   False
# 400                    False                   False                   False
# 0                      False                   False                   False
# 700                    False                   False                   False
#
#       k_bins_discretizer3__8  k_bins_discretizer3__9  k_bins_discretizer3__10  \
# 1799                    True                    True                    False
# 699                     True                   False                    False
# 1099                    True                    True                    False
# 999                     True                   False                    False
# 799                     True                   False                    False
# 1098                    True                    True                    False
# 1798                    True                    True                    False
# 1299                    True                    True                    False
# 1699                    True                    True                    False
# 1698                    True                    True                    False
# 899                     True                   False                    False
# 1899                    True                    True                    False
# 1999                    True                    True                    False
# 1697                    True                    True                    False
# 1399                    True                    True                    False
# 1797                    True                    True                     True
# 1599                    True                    True                    False
# 1398                    True                    True                    False
# 898                     True                    True                    False
# 1796                    True                    True                    False
# 1998                    True                    True                    False
# 1696                    True                    True                    False
# 1298                    True                    True                    False
# 1499                    True                    True                    False
# 1794                    True                    True                    False
# 1795                    True                    True                    False
# 1793                    True                    True                    False
# 1695                    True                    True                    False
# 1598                    True                    True                    False
# 698                     True                    True                    False
# ...                      ...                     ...                      ...
# 802                     True                   False                    False
# 1001                    True                    True                    False
# 8                      False                   False                    False
# 702                     True                   False                    False
# 1800                    True                    True                    False
# 801                     True                   False                    False
# 1102                    True                    True                    False
# 7                      False                   False                    False
# 200                     True                   False                    False
# 300                     True                   False                    False
# 1300                    True                    True                    False
# 401                     True                   False                    False
# 100                    False                   False                    False
# 6                      False                   False                    False
# 1101                    True                    True                    False
# 1000                    True                    True                    False
# 5                      False                   False                    False
# 4                      False                   False                    False
# 3                      False                   False                    False
# 1400                    True                    True                    False
# 800                     True                   False                    False
# 2                      False                   False                    False
# 1                       True                   False                    False
# 701                     True                   False                    False
# 900                     True                   False                     True
# 1900                    True                    True                    False
# 1100                    True                    True                     True
# 400                     True                   False                    False
# 0                      False                   False                    False
# 700                     True                   False                     True
#
#       k_bins_discretizer3__11  k_bins_discretizer3__12      score
# 1799                     True                    False   4.554330
# 699                      True                    False   4.832156
# 1099                     True                     True   4.848974
# 999                      True                     True   4.902275
# 799                      True                     True   4.933538
# 1098                     True                    False   4.938626
# 1798                     True                     True   4.942932
# 1299                     True                     True   4.955832
# 1699                     True                    False   4.979799
# 1698                     True                    False   4.994562
# 899                      True                    False   4.999600
# 1899                     True                     True   5.003601
# 1999                     True                     True   5.004767
# 1697                     True                     True   5.012400
# 1399                     True                     True   5.024686
# 1797                     True                     True   5.029108
# 1599                     True                     True   5.032786
# 1398                     True                     True   5.032786
# 898                      True                     True   5.039275
# 1796                     True                     True   5.045963
# 1998                     True                     True   5.062422
# 1696                     True                    False   5.062422
# 1298                     True                    False   5.062422
# 1499                     True                    False   5.062422
# 1794                     True                    False   5.062422
# 1795                     True                     True   5.062422
# 1793                     True                     True   5.070768
# 1695                     True                     True   5.073074
# 1598                     True                     True   5.078411
# 698                      True                    False   5.090006
# ...                       ...                      ...        ...
# 802                      True                     True  13.864781
# 1001                     True                     True  13.954638
# 8                       False                    False  13.982393
# 702                      True                    False  14.009371
# 1800                     True                     True  14.016149
# 801                      True                     True  14.057020
# 1102                     True                    False  14.057020
# 7                       False                    False  14.209780
# 200                     False                    False  14.252033
# 300                     False                     True  14.280574
# 1300                     True                     True  14.451849
# 401                      True                     True  14.499791
# 100                     False                    False  14.605564
# 6                       False                    False  14.707021
# 1101                     True                     True  14.733613
# 1000                     True                     True  15.015710
# 5                       False                    False  15.127813
# 4                       False                    False  15.350865
# 3                       False                    False  15.350942
# 1400                     True                    False  15.738735
# 800                      True                     True  15.870014
# 2                       False                    False  15.962748
# 1                       False                     True  16.112044
# 701                      True                     True  16.142886
# 900                      True                    False  16.407406
# 1900                     True                     True  16.592731
# 1100                     True                     True  17.080535
# 400                     False                     True  17.813187
# 0                       False                    False  18.058854
# 700                      True                    False  19.033905
#
# [2000 rows x 79 columns]
